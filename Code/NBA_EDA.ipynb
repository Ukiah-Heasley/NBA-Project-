# %%
# %run Import_Utilities.py

# %%
os.chdir('C:\\Users\\Ukiah\\Desktop\\Hobby\\NBA Project\\Data')
games = pd.read_csv('games.csv')
players = pd.read_csv('players.csv')
rankings = pd.read_csv('ranking.csv')
teams =  pd.read_csv('teams.csv')
games_details = pd.read_csv('games_details.csv')
os.chdir('C:\\Users\\Ukiah\\Desktop\\Hobby\\NBA Project\\Code')
# Out:
# C:\Users\Ukiah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
games_columns = games.columns 
players_columns = players.columns 
rankings_columns = rankings.columns 
teams_columns = teams.columns
# Out:
#                   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID    SEASON  \
# GAME_ID          1.000000     -0.026348        -0.031471  0.095721
# HOME_TEAM_ID    -0.026348      1.000000        -0.045911  0.000461
# VISITOR_TEAM_ID -0.031471     -0.045911         1.000000  0.002195
# SEASON           0.095721      0.000461         0.002195  1.000000
# TEAM_ID_home    -0.026348      1.000000        -0.045911  0.000461
# PTS_home         0.033727     -0.024372        -0.000120  0.345022
# FG_PCT_home      0.018384     -0.008239         0.035072  0.039355
# FT_PCT_home      0.036256     -0.009983         0.004108  0.065950
# FG3_PCT_home    -0.004041      0.002748         0.017292  0.024126
# AST_home        -0.032486     -0.097061         0.018287  0.192337
# REB_home        -0.006294     -0.026674        -0.002759  0.162529
# TEAM_ID_away    -0.031471     -0.045911         1.000000  0.002195
# PTS_away         0.004002     -0.006496        -0.032583  0.378888
# ...

# %%
teams
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# ...

# %%
def corr_func(teams,players,games, rankings, game_details):
    return teams.corr(),players.corr(),games.corr(), rankings.corr(), game_details.corr()

# %%
teams_corr,players_corr,games_corr, rankings_corr, games_details_corr = corr_func(teams,players,games, rankings, games_details)

# %%
Average_Player_Data = games_details.groupby("PLAYER_NAME").mean()
Average_Team_Data = games_details.groupby("TEAM_ID").mean()
Average_Team_Data =  Average_Team_Data.drop(["GAME_ID" , "PLAYER_ID"] , axis=1)
Average_Team_Data = Average_Team_Data.merge(teams[["TEAM_ID" , "NICKNAME"]] , on="TEAM_ID")

# %%
Average_Player_Data.join(pd.get_dummies(games_details["START_POSITION"] , drop_first=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-ea4113805a4b> in <module>
# ----> 1 Average_Player_Data.join(pd.get_dummies(games_details["START_POSITION"] , drop_first=F)).corr()
#
# NameError: name 'F' is not defined

# %%
sns.catplot(x="NICKNAME" , y="PLUS_M" , kind='bar' , data=Average_Team_Data)

# %%
#Look at all rows with any NaN values with our new Average_Stats for all players
NaN_Players = Average_Player_Data[Average_Player_Data.isna().any(axis=1)]
teams[teams['TEAM_ID']NaN_Players['TEAM_ID']]
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# ...

# %%
plt.hist(games['PTS_home'])
plt.hist(games['PTS_away'])
# Out:
# (array([1.000e+00, 1.000e+01, 4.260e+02, 3.363e+03, 9.544e+03, 8.228e+03,
#         3.461e+03, 5.950e+02, 6.400e+01, 5.000e+00]),
#  array([ 33. ,  46.5,  60. ,  73.5,  87. , 100.5, 114. , 127.5, 141. ,
#         154.5, 168. ]),
#  <a list of 10 Patch objects>)

# %%
alt.Chart(rankings).mark_bar().encode(
    x='year:O',
    y="wheat:Q",
    # The highlight will be set on the result of a conditional statement
    color=alt.condition(
        alt.datum.year == 1810,  # If the year is 1810 this test returns True,
        alt.value('orange'),     # which sets the bar orange.
        alt.value('steelblue')   # And if it's not true it sets the bar steelblue.
    )
).properties(width=600)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#    2018             copy.data = core.InlineData(values=[{}])
#    2019             return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2020         return super().to_dict(*args, **kwargs)
#    2021
#    2022     def add_selection(self, *selections):
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     372         copy = self.copy(deep=False)
#     373         original_data = getattr(copy, "data", Undefined)
# --> 374         copy.data = _prepare_data(original_data, context)
#     375
#     376         if original_data is not Undefined:
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in _prepare_data(data, context)
# ...

# %%
games_corr
# Out:
#                   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID    SEASON  \
# GAME_ID          1.000000     -0.026348        -0.031471  0.095721
# HOME_TEAM_ID    -0.026348      1.000000        -0.045911  0.000461
# VISITOR_TEAM_ID -0.031471     -0.045911         1.000000  0.002195
# SEASON           0.095721      0.000461         0.002195  1.000000
# TEAM_ID_home    -0.026348      1.000000        -0.045911  0.000461
# PTS_home         0.033727     -0.024372        -0.000120  0.345022
# FG_PCT_home      0.018384     -0.008239         0.035072  0.039355
# FT_PCT_home      0.036256     -0.009983         0.004108  0.065950
# FG3_PCT_home    -0.004041      0.002748         0.017292  0.024126
# AST_home        -0.032486     -0.097061         0.018287  0.192337
# REB_home        -0.006294     -0.026674        -0.002759  0.162529
# TEAM_ID_away    -0.031471     -0.045911         1.000000  0.002195
# PTS_away         0.004002     -0.006496        -0.032583  0.378888
# ...
